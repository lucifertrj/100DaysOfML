# %% [markdown]
# ## Pandas Part-2

# %% [markdown]
# We shall continue from where we left in Day 2 i.e, [Pandas Part-1](https://github.com/lucifertrj/100DaysOfML/tree/main/Day2:Pandas)

# %%
import pandas as pd

# %% [markdown]
# ### Handling Missing/Null Values

# %% [markdown]
# cells. It is good practice to deal with this missing values. Missing values might sometimes lead to false prediction of model. Using pandas you can check if the provided data has a missing values and you can check each column with empty values. There are two different methods to deal with Null data:
# - Drop i.e., delete the row/column from the dataset
# - Fill i.e., fill the row/column data in the dataset

# %% [markdown]
# Take us revise the basic Pandas methods covered in [Part-1](https://github.com/lucifertrj/100DaysOfML/tree/main/Day2:Pandas)

# %%
# read the dataset
# we shall read random.csv file from Part1
#make sure you have allocated the file path properly
dataset = pd.read_csv("random.csv")
copy_dataset = dataset.copy()  #creates a copy

# %%
#three different methods to view the data: head(), sample() and tail()
dataset.sample(15)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 81    8611161         B       13.340         15.86           86.49      520.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 521  91762702         M       24.630         21.60          165.50     1841.0
# 24     852552         M       16.650         21.38          110.00      904.6
# 32   85382601         M       17.020         23.98          112.80      899.3
# 383     90251         B       12.390         17.48           80.64      462.9
# 113    864292         B       10.510         20.19           68.64      334.2
# 557    925236         B        9.423         27.88           59.26      271.3
# 118    864877         M       15.780         22.91          105.70      782.6
# 218   8811842         M       19.800         21.56          129.70     1230.0
# 154   8711002         B       13.150         15.34           85.31      538.9
# ...

# %%
#check the infomation
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
dataset.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# As you can see Unnamed: 32 is filled with empty values. We shall now remove the column using dropna method.

# %% [markdown]
# ### Dropna

# %%
dataset.dropna(axis=1).head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33            184.6      2019.0
# 1  ...         24.99          23.41            158.8      1956.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
#
#    symmetry_worst  fractal_dimension_worst
# ...

# %%
dataset.dropna(axis=1).columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# We have successfully remove Unnamed: 32 column, that consisted of many NaN values. But there is one problem

# %%
dataset.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# We dropned the null values, but it didn't effect to the original dataset. To make the changes to original dataset, we use `inplace=True`

# %%
dataset.dropna(axis=1,inplace=True)

# %% [markdown]
# Note on using dropna arguments:
# ```py
# df.dropna(how="all",axis=0/1)
# df.dropna(how="any",axis=0/1)
# df.dropna(subset=['col1','col2'],axis=0/1)
# df.dropna(thresh=3) # keep only rows with atleast 3 NaN values
# ```

# %% [markdown]
# ### Fillna

# %% [markdown]
# The empty data from the dataset as to be dealt though some strategic planning. Pandas allows you to fill the empty values using fillna method. But you should use this command precisely, a wrong entered value might cause a major problem in Analysis.
# Consider two scenarios, first you have the dataset of Students with their total marks in 5 different subjects. And in second scenario you have the dataset of 8 Companies Sales from May 2020 To July 2021. In both the Datasets there might be empty values.
# How will you deal with Empty Values in the above given dataset?
#
# Consider the first dataset, the data is empty if in case the student is absent for the exam. You can then fill the empty values with 0.
# In second dataset, since you are dealing with sales, there might be empty data. This empty data should contain a price for the specific month, but is left empty. In such cases you can take the average mean of that column (here column is Company Name).

# %%
dataset.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33            184.6      2019.0
# 1  ...         24.99          23.41            158.8      1956.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
#
#    symmetry_worst  fractal_dimension_worst
# ...

# %% [markdown]
# Let us use copy_dataset which has Unnamed:32 column, so that we can work fillna on it

# %%
copy_dataset.head(3)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38           122.8     1001.0
# 1    842517         M        20.57         17.77           132.9     1326.0
# 2  84300903         M        19.69         21.25           130.0     1203.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
# 2  ...          25.53            152.5      1709.0            0.1444
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# ...

# %% [markdown]
# ```py
# df.fillna(0,inplace=True)
# df.fillna(df[column_name].mean(),inplace=True)
# inplace=True makes the changes permanently in the provided dataset.
#
# ```

# %%
copy_dataset.fillna(0) #use inplace=True to make changes permanent
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# #### `bfill` and `ffill` arguments in Fillna

# %%
check_ffill=pd.DataFrame({"ColOne":[6,None,None,10,5],
                 "ColTwo":[None,7,2,3,None],
                 "ColThree":[4,None,8,5,None],
                 "ColFour":[5,4,2,None,0]})

# %%
check_ffill
# Out:
#    ColOne  ColTwo  ColThree  ColFour
# 0     6.0     NaN       4.0      5.0
# 1     NaN     7.0       NaN      4.0
# 2     NaN     2.0       8.0      2.0
# 3    10.0     3.0       5.0      NaN
# 4     5.0     NaN       NaN      0.0

# %%
check_ffill.fillna(method="ffill")  
#forward fill, check the previous row value and update it. Thus ColTwo first data is still NaN
# Out:
#    ColOne  ColTwo  ColThree  ColFour
# 0     6.0     NaN       4.0      5.0
# 1     6.0     7.0       4.0      4.0
# 2     6.0     2.0       8.0      2.0
# 3    10.0     3.0       5.0      2.0
# 4     5.0     3.0       5.0      0.0

# %%
check_ffill.fillna(method="bfill")  #backward fill, thus the last data are still NaN
# Out:
#    ColOne  ColTwo  ColThree  ColFour
# 0     6.0     7.0       4.0      5.0
# 1    10.0     7.0       8.0      4.0
# 2    10.0     2.0       8.0      2.0
# 3    10.0     3.0       5.0      0.0
# 4     5.0     NaN       NaN      0.0

# %% [markdown]
# ### Groupby

# %%
df = pd.DataFrame({'Anime/Manga': ['One Piece', 'One Piece',
                              'AOT', 'AOT','Gintama','Gintama'],
                   'Episodes/Chapter': [1015,1047,75,129,366,704]})

# %%
df
# Out:
#   Anime/Manga  Episodes/Chapter
# 0   One Piece              1015
# 1   One Piece              1047
# 2         AOT                75
# 3         AOT               129
# 4     Gintama               366
# 5     Gintama               704

# %%
df.groupby(['Anime/Manga']).mean()
# Out:
#              Episodes/Chapter
# Anime/Manga
# AOT                       102
# Gintama                   535
# One Piece                1031

# %%
df.groupby(['Anime/Manga']).max()
# Out:
#              Episodes/Chapter
# Anime/Manga
# AOT                       129
# Gintama                   704
# One Piece                1047

# %%
df.groupby(['Anime/Manga']).agg(['mean','max','min','count'])
# Out:
#             Episodes/Chapter
#                         mean   max   min count
# Anime/Manga
# AOT                      102   129    75     2
# Gintama                  535   704   366     2
# One Piece               1031  1047  1015     2

# %% [markdown]
# ### Value Count

# %%
df
# Out:
#   Anime/Manga  Episodes/Chapter
# 0   One Piece              1015
# 1   One Piece              1047
# 2         AOT                75
# 3         AOT               129
# 4     Gintama               366
# 5     Gintama               704

# %%
df.value_counts()
# Out:
# Anime/Manga  Episodes/Chapter
# AOT          75                  1
#              129                 1
# Gintama      366                 1
#              704                 1
# One Piece    1015                1
#              1047                1
# dtype: int64

# %%
new_df = pd.DataFrame({'num_legs': [2, 4, 4, 6],
                   'num_wings': [2, 0, 0, 0]},
                  index=['falcon', 'dog', 'cat', 'ant'])

# %%
new_df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0
# cat            4          0
# ant            6          0

# %%
new_df.value_counts()
# Out:
# num_legs  num_wings
# 4         0            2
# 2         2            1
# 6         0            1
# dtype: int64

# %% [markdown]
# ### Duplicate, Drop and Rename

# %%
#duplicate

# %% [markdown]
# ```py
# check_duplicate_in_all_columns = df[df.duplicated()]
# check_duplicate_in_specific_columns = df[df.duplicated(['col1', 'col2','col3'])]
# ```

# %%
dataset.head(3)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38           122.8     1001.0
# 1    842517         M        20.57         17.77           132.9     1326.0
# 2  84300903         M        19.69         21.25           130.0     1203.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
# 2  ...          25.53            152.5      1709.0            0.1444
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# ...

# %%
#let us see duplicated in all columns
dup_columns = dataset[dataset.duplicated()]
dup_columns
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# We have no duplication in any column, which is great

# %%
#let us read one more CSV file to play with duplicate, drop and rename

# %%
play_data = pd.read_csv("heart_disease.csv")
play_data.head(4)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1

# %%
play_data[play_data.duplicated(['age','slope'])]  #this will show dataset with duplicated age and slope value
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 9     57    1   2       150   168    0        1      174      0      1.6
# 16    58    0   2       120   340    0        1      172      0      0.0
# 21    44    1   2       130   233    0        1      179      1      0.4
# 30    41    0   1       105   198    0        1      168      0      0.0
# 31    65    1   0       120   177    0        1      140      0      0.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 9        2   0     2       1
# 16       2   0     2       1
# ...

# %%
#drop

# %% [markdown]
# Here all the columns except target are features and target is the label which we need to protect.[We shall look this in Machine Learning]

# %% [markdown]
# So lets select all the column other than target using drop method

# %%
features = play_data.drop('target',axis=1) #note I didn't use inplace=True, because I need target column
#axis=1 for column

# %%
features
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
play_data.drop('fbs',axis=1,inplace=True)

# %%
play_data.head(2)
# Out:
#    age  sex  cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63    1   3       145   233        0      150      0      2.3      0   0
# 1   37    1   2       130   250        1      187      0      3.5      0   0
#
#    thal  target
# 0     1       1
# 1     2       1

# %% [markdown]
# We removed the fbs column

# %%
#to remove multiple column
play_data.drop(['cp','sex'],axis=1) #i will not use inplace=True, because I shall use the data for rename method as well
# Out:
#      age  trestbps  chol  restecg  thalach  exang  oldpeak  slope  ca  thal  \
# 0     63       145   233        0      150      0      2.3      0   0     1
# 1     37       130   250        1      187      0      3.5      0   0     2
# 2     41       130   204        0      172      0      1.4      2   0     2
# 3     56       120   236        1      178      0      0.8      2   0     2
# 4     57       120   354        1      163      1      0.6      2   0     2
# ..   ...       ...   ...      ...      ...    ...      ...    ...  ..   ...
# 298   57       140   241        1      123      1      0.2      1   0     3
# 299   45       110   264        1      132      0      1.2      1   0     3
# 300   68       144   193        1      141      0      3.4      1   2     3
# 301   57       130   131        1      115      1      1.2      1   1     3
# 302   57       130   236        0      174      0      0.0      1   1     2
#
#      target
# 0         1
# 1         1
# 2         1
# ...

# %% [markdown]
# We removed cp and sex column from the dataset both not permanently

# %%
#rename

# %%
play_data.head(3)
# Out:
#    age  sex  cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63    1   3       145   233        0      150      0      2.3      0   0
# 1   37    1   2       130   250        1      187      0      3.5      0   0
# 2   41    0   1       130   204        0      172      0      1.4      2   0
#
#    thal  target
# 0     1       1
# 1     2       1
# 2     2       1

# %%
play_data.rename(columns={"sex":"gender"},inplace=True)

# %%
play_data.head(3)
# Out:
#    age  gender  cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope  \
# 0   63       1   3       145   233        0      150      0      2.3      0
# 1   37       1   2       130   250        1      187      0      3.5      0
# 2   41       0   1       130   204        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1

# %%
play_data.rename(index={0:"a",1:"b"},inplace=True)

# %%
play_data.head(3)
# Out:
#    age  gender  cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope  \
# a   63       1   3       145   233        0      150      0      2.3      0
# b   37       1   2       130   250        1      187      0      3.5      0
# 2   41       0   1       130   204        0      172      0      1.4      2
#
#    ca  thal  target
# a   0     1       1
# b   0     2       1
# 2   0     2       1

# %% [markdown]
# ### Parsing Dates In Pandas

# %% [markdown]
# On working with dates let us take a dataset that has Date column in it. Luckily in [Pandas Part-1](https://github.com/lucifertrj/100DaysOfML/tree/main/Day2:Pandas) we used a dataset with named data.csv. We shall import the data.csv file, make sure you provide file path properly.

# %%
working_with_date = pd.read_csv("data.csv")

# %%
working_with_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# If you check the datatype of date_added it is an object. Basically in almost many dataset date shall be in object data type. We can convert the object to datetime with help of Powerful Pandas

# %% [markdown]
# Let us create a new column

# %%
working_with_date['date'] = pd.to_datetime(working_with_date['date_added'])

# %%
working_with_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  date          8797 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 894.6+ KB

# %% [markdown]
# Since we now have a seperate column for date lets first delete the object date_added column

# %%
working_with_date.drop('date_added',axis=1,inplace=True)

# %%
working_with_date.date
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date, Length: 8807, dtype: datetime64[ns]

# %% [markdown]
# Manipulating Year, Month and Day of datetime column

# %%
working_with_date['year'] = working_with_date['date'].dt.year

# %%
working_with_date['month'] = working_with_date['date'].dt.month

# %%
working_with_date['day'] = working_with_date['date'].dt.day

# %%
working_with_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
#  11  date          8797 non-null   datetime64[ns]
#  12  year          8797 non-null   float64
#  13  month         8797 non-null   float64
#  14  day           8797 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
working_with_date[['date','year','month','day']].head(10)
# Out:
#         date    year  month   day
# 0 2021-09-25  2021.0    9.0  25.0
# 1 2021-09-24  2021.0    9.0  24.0
# 2 2021-09-24  2021.0    9.0  24.0
# 3 2021-09-24  2021.0    9.0  24.0
# 4 2021-09-24  2021.0    9.0  24.0
# 5 2021-09-24  2021.0    9.0  24.0
# 6 2021-09-24  2021.0    9.0  24.0
# 7 2021-09-24  2021.0    9.0  24.0
# 8 2021-09-24  2021.0    9.0  24.0
# 9 2021-09-24  2021.0    9.0  24.0

# %% [markdown]
# Note: This is the last part of Pandas. We shall look at some more methods while working on EDA. Up next we have Matplotlib, Seaborn and Plotly to cover

# %% [markdown]
# ```
# Tip:
# For any documentation help you can use "?" symbol
# Syntax:
# method?
# ```

# %%
pd.pivot?
